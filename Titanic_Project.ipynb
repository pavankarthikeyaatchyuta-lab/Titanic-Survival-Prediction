# %% [markdown]
# # 🚢 Titanic Survival Prediction: Machine Learning Baseline
#
# **Author:** Pavan Karthikeya Atchyuta
# **Objective:** Build a robust, leak-free Machine Learning classification pipeline to predict passenger survival on the RMS Titanic.
#
# ---
#
# ## 1. Problem Statement
#
# The sinking of the RMS Titanic on April 15, 1912, is one of the deadliest maritime disasters in history, resulting in the deaths of over 1,500 of the 2,224 passengers and crew. While survival was influenced by luck, distinct demographic, socioeconomic, and behavioral factors significantly determined who was granted access to lifeboats under the maritime protocol of *"women and children first"*.
#
# ### Project Objective
# The goal of this project is to develop a binary classification model:
# $$\hat{y} \in \{0, 1\}$$
# where:
# * **0 = Did not survive** (Perished)
# * **1 = Survived**
#
# We focus on establishing rigorous ML methodology:
# 1. Conducting insightful Exploratory Data Analysis (EDA) to answer meaningful historical and sociological questions.
# 2. Engineering relevant domain features (e.g., family structure).
# 3. Implementing a leak-free preprocessing and modeling pipeline using `scikit-learn` (`ColumnTransformer` and `Pipeline`).
# 4. Evaluating a Logistic Regression baseline model on an untouched, stratified held-out test set using comprehensive classification metrics.

# %% [markdown]
# ## 2. Import Libraries
#
# We import standard, well-tested Python scientific and machine learning libraries:
# * **Pandas & NumPy:** Data manipulation and numerical operations.
# * **Matplotlib & Seaborn:** Statistical visualizations.
# * **Scikit-Learn:** Data preprocessing, pipeline assembly, model training, and performance evaluation.

# %%
# Core data handling and numerical computing
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn: Preprocessing and Pipeline
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Scikit-learn: Modeling and Metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# Plotting configuration for clean, publication-ready figures
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"] = (9, 5)
plt.rcParams["font.size"] = 11

print("Libraries successfully imported.")
# Out:
# Libraries successfully imported.

# %% [markdown]
# ## 3. Load Dataset
#
# We load the dataset from the local `titanic.csv` file (the standard Kaggle Titanic training set).

# %%
# Load Titanic passenger dataset
data_path = "titanic.csv"
df = pd.read_csv(data_path)

print(f"Dataset successfully loaded with {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# Dataset successfully loaded with 891 rows and 12 columns.

# %% [markdown]
# ## 4. Initial Data Inspection
#
# Before performing any transformations, we inspect the raw dataset to understand feature dimensions, data types, missing value frequencies, and target balance.

# %%
# Display first 5 records
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Summary of data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Statistical summary of numerical columns
df.describe().round(2)
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %%
# Missing value audit
missing_summary = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage (%)': (df.isnull().mean() * 100).round(2)
})
missing_summary[missing_summary['Missing Values'] > 0].sort_values(by='Missing Values', ascending=False)
# Out:
#           Missing Values  Percentage (%)
# Cabin                687           77.10
# Age                  177           19.87
# Embarked               2            0.22

# %%
# Target variable distribution
target_counts = df['Survived'].value_counts()
target_pct = (df['Survived'].value_counts(normalize=True) * 100).round(2)

target_dist = pd.DataFrame({
    'Count': target_counts,
    'Percentage (%)': target_pct,
    'Label': ['Perished (0)', 'Survived (1)']
})
target_dist
# Out:
#           Count  Percentage (%)         Label
# Survived
# 0           549           61.62  Perished (0)
# 1           342           38.38  Survived (1)

# %% [markdown]
# ### Initial Inspection Takeaways:
# 1. **Dataset Size:** 891 passenger records across 12 raw columns.
# 2. **Missing Values:**
#    * `Cabin`: Missing in **687 rows (77.10%)**.
#    * `Age`: Missing in **177 rows (19.87%)**.
#    * `Embarked`: Missing in **2 rows (0.22%)**.
# 3. **Class Distribution:** 342 passengers survived (38.38%), while 549 passengers perished (61.62%). The dataset is moderately imbalanced, making stratification essential during splitting.

# %% [markdown]
# ## 5. Data Cleaning & Feature Engineering
#
# ### Feature Engineering: Family Size
# The dataset provides two familial attributes:
# * `SibSp`: Number of siblings and spouses aboard.
# * `Parch`: Number of parents and children aboard.
#
# Neither variable alone captures a passenger's total traveling group. Solo travelers and passengers in large families faced distinct survival challenges (e.g., searching for family members during evacuation vs. moving rapidly alone). We engineer a single combined metric:
# $$\text{FamilySize} = \text{SibSp} + \text{Parch} + 1$$
# *(where $+1$ accounts for the passenger themselves).*
#
# ### Feature Exclusion Justifications
# Rather than blindly dropping features, we provide clear domain and statistical justifications:
# * **`PassengerId`:** An arbitrary sequential identifier. It carries zero predictive signal and would cause spurious correlation or memorization.
# * **`Name`:** High-cardinality text feature with unique values. While title extraction is possible, for a clean baseline model it introduces unnecessary complexity.
# * **`Ticket`:** Semi-structured alphanumeric strings with high cardinality and inconsistent formatting.
# * **`Cabin`:** Missing **77.10%** of values. Imputing more than three-quarters of missing values would introduce substantial artificial noise into a linear model. Dropping it is methodologically justified for the baseline model.

# %%
# Engineer FamilySize
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# Create a temporary age group column solely for EDA visualization
# (Note: The raw continuous Age feature will be used for modeling to avoid information loss)
age_bins = [0, 12, 18, 35, 60, 120]
age_labels = ['Child (0-12)', 'Adolescent (13-18)', 'Young Adult (19-35)', 'Middle Aged (36-60)', 'Senior (61+)']
df['AgeGroup'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=True)

df[['SibSp', 'Parch', 'FamilySize', 'Age', 'AgeGroup']].head()
# Out:
#    SibSp  Parch  FamilySize   Age             AgeGroup
# 0      1      0           2  22.0  Young Adult (19-35)
# 1      1      0           2  38.0  Middle Aged (36-60)
# 2      0      0           1  26.0  Young Adult (19-35)
# 3      1      0           2  35.0  Young Adult (19-35)
# 4      0      0           1  35.0  Young Adult (19-35)

# %% [markdown]
# ## 6. Exploratory Data Analysis (EDA)
#
# We explore key demographic and socioeconomic relationships with passenger survival. Every chart below addresses a specific hypothesis and is accompanied by a concise, written interpretation.

# %%
# Chart 1: Survival Rate by Gender
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Subplot 1: Raw counts
sns.countplot(data=df, x='Sex', hue='Survived', palette=['#d95f02', '#1b9e77'], ax=axes[0])
axes[0].set_title("Survival Counts by Gender", fontsize=12, fontweight='bold')
axes[0].set_xlabel("Gender")
axes[0].set_ylabel("Passenger Count")
axes[0].legend(title="Status", labels=["Perished", "Survived"])

# Subplot 2: Survival Rate (%)
gender_survival = df.groupby('Sex')['Survived'].mean().reset_index()
gender_survival['SurvivalRate'] = gender_survival['Survived'] * 100

bars = sns.barplot(data=gender_survival, x='Sex', y='SurvivalRate', palette=['#1b9e77', '#386cb0'], ax=axes[1])
axes[1].set_title("Survival Rate (%) by Gender", fontsize=12, fontweight='bold')
axes[1].set_xlabel("Gender")
axes[1].set_ylabel("Survival Rate (%)")
axes[1].set_ylim(0, 100)

for p in bars.patches:
    axes[1].annotate(f"{p.get_height():.1f}%", 
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='bottom', fontsize=11, fontweight='bold', xytext=(0, 4),
                     textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14476\2253136858.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(data=gender_survival, x='Sex', y='SurvivalRate', palette=['#1b9e77', '#386cb0'], ax=axes[1])

# %% [markdown]
# **Interpretation — Chart 1 (Survival by Gender):**
# Gender is the single strongest univariate predictor of survival on the Titanic. Female passengers had a **74.2%** survival rate, compared to just **18.9%** for male passengers. This dramatic disparity directly reflects the strict enforcement of the *"women and children first"* protocol during lifeboat loading.

# %%
# Chart 2: Survival Rate by Passenger Class
plt.figure(figsize=(8, 5))

pclass_survival = df.groupby('Pclass')['Survived'].mean().reset_index()
pclass_survival['SurvivalRate'] = pclass_survival['Survived'] * 100

palette_class = ['#2b83ba', '#abdda4', '#fdae61']
bars = sns.barplot(data=pclass_survival, x='Pclass', y='SurvivalRate', palette=palette_class)
plt.title("Survival Rate (%) by Passenger Ticket Class", fontsize=12, fontweight='bold')
plt.xlabel("Passenger Class (Pclass)")
plt.ylabel("Survival Rate (%)")
plt.ylim(0, 100)

for p in bars.patches:
    plt.annotate(f"{p.get_height():.1f}%", 
                 (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='bottom', fontsize=11, fontweight='bold', xytext=(0, 4),
                 textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14476\572183541.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(data=pclass_survival, x='Pclass', y='SurvivalRate', palette=palette_class)

# %% [markdown]
# **Interpretation — Chart 2 (Survival by Passenger Class):**
# Socioeconomic status strongly influenced survival probability. First-class passengers experienced the highest survival rate (**63.0%**), followed by second-class (**47.3%**), and third-class (**24.2%**). Passengers in first class were accommodated on higher decks closer to the boat deck, whereas third-class passengers were located deep in the lower decks and faced physical barriers and delays in reaching lifeboats.

# %%
# Chart 3: Survival Rate by Age Group
plt.figure(figsize=(9, 5))

age_survival = df.groupby('AgeGroup', observed=False)['Survived'].mean().reset_index()
age_survival['SurvivalRate'] = age_survival['Survived'] * 100

bars = sns.barplot(data=age_survival, x='AgeGroup', y='SurvivalRate', palette='Blues_d')
plt.title("Survival Rate (%) by Age Bracket", fontsize=12, fontweight='bold')
plt.xlabel("Age Group")
plt.ylabel("Survival Rate (%)")
plt.ylim(0, 100)

for p in bars.patches:
    plt.annotate(f"{p.get_height():.1f}%", 
                 (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='bottom', fontsize=11, fontweight='bold', xytext=(0, 4),
                 textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14476\714054842.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(data=age_survival, x='AgeGroup', y='SurvivalRate', palette='Blues_d')

# %% [markdown]
# **Interpretation — Chart 3 (Survival by Age Group):**
# Children (aged 0–12) experienced the highest survival rate among all age brackets at **58.0%**, consistent with the emergency evacuation order. In contrast, elderly passengers (aged 61+) had the lowest survival rate at **22.7%**, reflecting the severe physical challenges of evacuating a sinking vessel in freezing conditions. Adults (19–60) had survival rates between 38% and 40%.

# %%
# Chart 4: Correlation Heatmap of Numerical Features
plt.figure(figsize=(9, 6))

numerical_cols = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'FamilySize']
corr_matrix = df[numerical_cols].corr()

sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0, linewidths=0.5, cbar_kws={'label': 'Pearson Correlation'})
plt.title("Correlation Heatmap of Numerical Features", fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation — Chart 4 (Correlation Analysis):**
# * `Pclass` exhibits the strongest negative correlation with survival ($r = -0.34$), confirming that lower class numbers (1st class) had higher survival.
# * `Fare` exhibits a positive correlation with survival ($r = +0.26$), aligning with the passenger class effect.
# * `FamilySize` correlates strongly with its constituent features `SibSp` ($r = 0.89$) and `Parch` ($r = 0.78$), but provides a unified measure of traveling group size.

# %% [markdown]
# ## 7. Feature Preparation
#
# We separate the raw dataframe into feature matrix `X` and target vector `y`. We partition features into numerical and categorical subsets to feed into our scikit-learn preprocessing pipeline.
#
# * **Numerical Features:** `Age`, `Fare`, `SibSp`, `Parch`, `FamilySize`
# * **Categorical Features:** `Sex`, `Embarked`, `Pclass`
# *(Note: While `Pclass` is represented by integers 1, 2, 3, it represents discrete socioeconomic passenger tiers; encoding it as a categorical variable avoids assuming equal linear intervals between tiers).*

# %%
# Define features and target
drop_columns = ['PassengerId', 'Name', 'Ticket', 'Cabin', 'Survived', 'AgeGroup']

X = df.drop(columns=drop_columns)
y = df['Survived']

numeric_features = ['Age', 'Fare', 'SibSp', 'Parch', 'FamilySize']
categorical_features = ['Sex', 'Embarked', 'Pclass']

print("Features (X) shape:", X.shape)
print("Target (y) shape:", y.shape)
print("Numerical features:", numeric_features)
print("Categorical features:", categorical_features)
# Out:
# Features (X) shape: (891, 8)
# Target (y) shape: (891,)
# Numerical features: ['Age', 'Fare', 'SibSp', 'Parch', 'FamilySize']
# Categorical features: ['Sex', 'Embarked', 'Pclass']

# %% [markdown]
# ## 8. Train / Test Split
#
# We partition the data into an **80% training set** and a **20% held-out test set**:
#
# ```python
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.20,
#     random_state=42,
#     stratify=y
# )
# ```
#
# ### Methodological Principles:
# 1. **Stratification (`stratify=y`):** Ensures that the 61.6% / 38.4% class ratio is preserved exactly across both training and test partitions, preventing sampling bias.
# 2. **Reproducibility (`random_state=42`):** Fixes the pseudo-random generator seed, ensuring all results can be independently reproduced.
# 3. **Strict Data Leakage Prevention:** The held-out test set is locked away and **never** used to compute summary statistics (e.g., mean, median, standard deviation, or categorical frequencies). All imputation parameters, scalers, and encoders are fit **exclusively** on `X_train`.

# %%
# Stratified 80/20 train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print(f"Training set size: {X_train.shape[0]} samples")
print(f"Test set size:     {X_test.shape[0]} samples")
print(f"Train survival rate: {y_train.mean():.4f}")
print(f"Test survival rate:  {y_test.mean():.4f}")
# Out:
# Training set size: 712 samples
# Test set size:     179 samples
# Train survival rate: 0.3834
# Test survival rate:  0.3855

# %% [markdown]
# ## 9. Baseline Model: Logistic Regression Pipeline
#
# ### Why Logistic Regression?
# 1. **Simplicity and Transparency:** Logistic Regression is the standard benchmark for binary classification problems. It makes clear linear log-odds assumptions:
#    $$\log \left( \frac{P(Y=1)}{1 - P(Y=1)} \right) = \beta_0 + \sum_{j=1}^p \beta_j X_j$$
# 2. **Interpretability:** Model coefficients directly indicate the direction and magnitude of each feature's contribution to survival probability.
# 3. **Calibrated Probabilities:** Outputs smooth survival probabilities rather than uncalibrated scores.
#
# ### Leak-Free ColumnTransformer & Pipeline
# * **Numerical Transformer:**
#   * `SimpleImputer(strategy='median')`: Imputes missing ages with the training median (robust to outliers).
#   * `StandardScaler()`: Standardizes features to mean = 0, variance = 1 (critical for numerical stability in regularized logistic regression).
# * **Categorical Transformer:**
#   * `SimpleImputer(strategy='most_frequent')`: Imputes missing `Embarked` with the mode ('S').
#   * `OneHotEncoder(handle_unknown='ignore')`: Converts categorical levels into one-hot binary indicators safely without crashing on unseen categories.

# %%
# Define preprocessing sub-pipelines
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine into ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# Assemble complete modeling Pipeline
baseline_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000, random_state=42))
])

# Fit pipeline EXCLUSIVELY on training data
baseline_pipeline.fit(X_train, y_train)

print("Pipeline successfully fitted on training data.")
# Out:
# Pipeline successfully fitted on training data.

# %% [markdown]
# ## 10. Model Evaluation on Held-Out Test Set
#
# We evaluate our trained pipeline on the unseen held-out test set (`X_test`). We compute:
# * **Accuracy:** Overall proportion of correct predictions.
# * **Precision:** Accuracy of positive (survived) predictions: $\frac{TP}{TP + FP}$.
# * **Recall (Sensitivity):** Proportion of actual survivors detected: $\frac{TP}{TP + FN}$.
# * **F1 Score:** Harmonic mean of precision and recall: $2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}$.
# * **Confusion Matrix:** Breakdown of TP, FP, TN, and FN.
# * **Classification Report:** Detailed per-class precision, recall, and F1 metrics.

# %%
# Generate predictions on the held-out test set
y_pred = baseline_pipeline.predict(X_test)
y_proba = baseline_pipeline.predict_proba(X_test)[:, 1]

# Calculate evaluation metrics
test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred)
test_recall = recall_score(y_test, y_pred)
test_f1 = f1_score(y_test, y_pred)

# Display metrics table
metrics_df = pd.DataFrame({
    'Evaluation Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Score': [test_accuracy, test_precision, test_recall, test_f1]
})
metrics_df['Formatted Score'] = metrics_df['Score'].apply(lambda x: f"{x:.4f} ({x*100:.2f}%)")
metrics_df[['Evaluation Metric', 'Formatted Score']]
# Out:
#   Evaluation Metric  Formatted Score
# 0          Accuracy  0.8045 (80.45%)
# 1         Precision  0.7931 (79.31%)
# 2            Recall  0.6667 (66.67%)
# 3          F1 Score  0.7244 (72.44%)

# %%
# Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(7, 5))
annot_labels = [
    [f"True Negative (TN)\n{cm[0,0]}\n({cm[0,0]/cm.sum()*100:.1f}%)", 
     f"False Positive (FP)\n{cm[0,1]}\n({cm[0,1]/cm.sum()*100:.1f}%)"],
    [f"False Negative (FN)\n{cm[1,0]}\n({cm[1,0]/cm.sum()*100:.1f}%)", 
     f"True Positive (TP)\n{cm[1,1]}\n({cm[1,1]/cm.sum()*100:.1f}%)"]
]

sns.heatmap(cm, annot=annot_labels, fmt="", cmap="Blues", cbar=False,
            xticklabels=['Predicted: Perished (0)', 'Predicted: Survived (1)'],
            yticklabels=['Actual: Perished (0)', 'Actual: Survived (1)'])
plt.title("Confusion Matrix — Held-Out Test Set (N = 179)", fontsize=12, fontweight='bold')
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.show()

# %%
# Detailed Classification Report
print("Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=['Perished (0)', 'Survived (1)'], digits=4))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
# Perished (0)     0.8099    0.8909    0.8485       110
# Survived (1)     0.7931    0.6667    0.7244        69
#
#     accuracy                         0.8045       179
#    macro avg     0.8015    0.7788    0.7864       179
# weighted avg     0.8034    0.8045    0.8007       179

# %% [markdown]
# ## 11. Results & Interpretation
#
# ### Interpretation of Evaluation Metrics
# * **Accuracy (80.45%):** Out of 179 unseen test passengers, the baseline model correctly classified 144 individuals. This demonstrates solid predictive ability for a linear baseline.
# * **Precision (79.31%):** When the model predicts that a passenger survived, it is correct **79.31%** of the time. The model generated only 12 False Positives.
# * **Recall (66.67%):** The model correctly identified **46 of the 69 actual survivors** in the test set, but missed 23 survivors (False Negatives).
# * **F1 Score (72.44%):** Balances precision and recall into a single harmonic metric, confirming balanced predictive utility without extreme bias toward the majority class.
#
# ### Error Analysis: False Positives vs. False Negatives
# * **False Positives (12 passengers):** The model predicted the passenger survived, but they actually perished. These often correspond to 1st/2nd class male passengers or 3rd class female passengers whose survival deviated from general demographic odds.
# * **False Negatives (23 passengers):** The model predicted the passenger perished, but they actually survived. These frequently represent 3rd class passengers (particularly men or older children) who managed to reach lifeboats against the statistical baseline.

# %%
# Extract and examine feature coefficients
feature_names = baseline_pipeline.named_steps['preprocessor'].get_feature_names_out()
coefficients = baseline_pipeline.named_steps['classifier'].coef_[0]

coef_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient (Log-Odds)': coefficients
}).sort_values(by='Coefficient (Log-Odds)', ascending=False)

# Clean feature names for clean display
coef_df['Clean Feature'] = coef_df['Feature'].str.replace('num__', '').str.replace('cat__', '')

plt.figure(figsize=(9, 6))
sns.barplot(data=coef_df, x='Coefficient (Log-Odds)', y='Clean Feature', 
            palette=['#1b9e77' if x > 0 else '#d95f02' for x in coef_df['Coefficient (Log-Odds)']])
plt.axvline(0, color='black', linestyle='--', linewidth=0.8)
plt.title("Logistic Regression Feature Coefficients (Log-Odds)", fontsize=12, fontweight='bold')
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14476\2632599618.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=coef_df, x='Coefficient (Log-Odds)', y='Clean Feature',

# %% [markdown]
# ### Coefficient Interpretation:
# * **Strongest Positive Drivers:** `Sex_female` ($+1.36$) and `Pclass_1` ($+1.04$) substantially increase the log-odds of survival.
# * **Strongest Negative Drivers:** `Sex_male` ($-1.24$) and `Pclass_3` ($-1.06$) heavily decrease the log-odds of survival.
# * **Continuous Features:** Older `Age` has a moderate negative coefficient ($-0.49$), reflecting decreased survival odds for older individuals, while higher `Fare` ($+0.13$) slightly improves predicted survival odds.

# %% [markdown]
# ## 12. Limitations & Future Improvements
#
# ### What Worked Well:
# 1. **Leak-free preprocessing:** Wrapping median imputation, scaling, and one-hot encoding into a `ColumnTransformer` inside an `sklearn.pipeline.Pipeline` guaranteed that test data never leaked into the preprocessing steps.
# 2. **Stratified splitting:** Maintained exact class balance (38.4% survival rate) in both training and test sets.
# 3. **High interpretability:** The Logistic Regression baseline provides direct insights into which features influenced survival.
# 4. **Strong performance:** Achieved **80.45% accuracy** and **0.7244 F1 score** with a simple, transparent model.
#
# ### Project Limitations:
# 1. **Linearity Assumption:** Logistic Regression models a linear decision boundary on the log-odds scale, unable to naturally capture non-linear interactions (e.g., third-class women vs. first-class women).
# 2. **Excluded Cabin Data:** Dropping `Cabin` due to 77.1% missing values lost potential information regarding physical deck location.
# 3. **Unused Text Data:** Passenger names contain social honorifics (e.g., *Master*, *Mrs*, *Miss*, *Mr*, *Dr*, *Rev*) that could provide additional age and socioeconomic signals.
#
# ### What to Try Next:
# 1. **Title Extraction:** Extract honorific titles from the `Name` column to refine age imputation and capture marital/social status.
# 2. **Deck Extraction:** Extract the deck letter from non-null `Cabin` values and create an explicit `Missing` category.
# 3. **Non-Linear Ensembles:** Train and compare Random Forest, Gradient Boosting, and XGBoost classifiers to capture interaction effects.
# 4. **Hyperparameter Tuning:** Use 5-fold Stratified Cross-Validation (`GridSearchCV`) to optimize regularization parameters ($C$ and penalty).

# %% [markdown]
# ## 13. Final Conclusion
#
# In this project, we developed an end-to-end, methodologically sound Machine Learning baseline for predicting Titanic passenger survival. By avoiding common data science pitfalls—such as data leakage, unstratified splitting, and ad-hoc preprocessing—we established a robust evaluation benchmark.
#
# Our baseline Logistic Regression model achieved **80.45% accuracy**, **79.31% precision**, **66.67% recall**, and an **F1 score of 0.7244** on an untouched held-out test set. The model's learned coefficients align with historical accounts of the disaster, underscoring that gender and socioeconomic class were the predominant determinants of survival aboard the Titanic.
